# %%
pip install pandas
# Out:
# ...
#                                               0.0/11.6 MB ? eta -:--:--
#      -                                        0.3/11.6 MB 9.6 MB/s eta 0:00:02
#      -                                        0.5/11.6 MB 5.8 MB/s eta 0:00:02
#      -                                        0.5/11.6 MB 4.3 MB/s eta 0:00:03
#      -                                        0.6/11.6 MB 3.3 MB/s eta 0:00:04
#      --                                       0.6/11.6 MB 2.6 MB/s eta 0:00:05
#      --                                       0.7/11.6 MB 2.3 MB/s eta 0:00:05
#      --                                       0.7/11.6 MB 2.2 MB/s eta 0:00:06
#      --                                       0.8/11.6 MB 2.2 MB/s eta 0:00:05
#      --                                       0.9/11.6 MB 2.0 MB/s eta 0:00:06
#      ---                                      0.9/11.6 MB 1.9 MB/s eta 0:00:06
#      ---                                      0.9/11.6 MB 1.9 MB/s eta 0:00:06
# ...

# %%
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\logonrmlocal\FIAP\Segundo Semestre\Python\22.04\manutencao_preditiva.csv')

# %%
df.columns
# Out:
# Index(['UDI', 'ID Produto', 'Tipo', 'Temperatura Ar [K]',
#        'Temperatura Processo [K]', 'Velocidade Rotacao [rpm]', 'Torque [Nm]',
#        'Desgaste Ferramenta [min]', 'Alvo', 'Tipo da Falha'],
#       dtype='object')

# %%
x = df

#output
y = df['Tipo da Falha']

# %%
#Selecionar dados para testar uma IA

from sklearn.model_selection import train_test_split

x_treino, x_teste, y_treino, y_teste = train_test_split(x, y, test_size = 0.3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 5
#       1 #Selecionar dados para testar uma IA
#       3 from sklearn.model_selection import train_test_split
# ----> 5 x_treino, x_teste, y_treino, y_teste = train_test_split(x, y, test_size = 0.3)
#
# NameError: name 'x' is not defined

# %%
pip install -U scikit-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.1.2 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from sklearn.neural_network import MLPClassifier

mlp = MLPClassifier(hidden_layer_sizes=(100), max_iter=100, activation='relu')

# %%
treino = mlp.fit(x_treino, y_treino)
